# %%
# Week 2 Project 
# Temperature Converter Convert Celsius to Fahrenheit and Fahrenheit to Celsius.

# %%
# Formulas
# Fahrenheit = (Celsius * 9 / 5) + 32 
# Celsius = (Fahrenheit - 32) * 5 / 9

# %%
print("~~~~~~~~~~~TEMPERATURE CONVERTER~~~~~~~~~~~~~")
# celcius to fahrenheit
celsius = float(input("Enter temperature in Celsius: "))
fahrenheit_answer = (celsius * 9 / 5) + 32
print(celsius, "Celsius is equal to", fahrenheit_answer, "Fahrenheit")

# Fahrenheit to Celsius
fahrenheit = float(input("Enter temperature in Fahrenheit: "))
celsius_answer = (fahrenheit - 32) * 5 / 9
print(fahrenheit, "Fahrenheit is equal to", celsius_answer, "Celsius")
# Out:
# ~~~~~~~~~~~TEMPERATURE CONVERTER~~~~~~~~~~~~~
# Enter temperature in Celsius:  99
# 99.0 Celsius is equal to 210.2 Fahrenheit
# Enter temperature in Fahrenheit:  72
# 72.0 Fahrenheit is equal to 22.22222222222222 Celsius
